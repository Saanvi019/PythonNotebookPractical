# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
#   Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from mlxtend) (2.0.3)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from mlxtend) (1.10.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from mlxtend) (1.24.4)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from mlxtend) (3.7.5)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from mlxtend) (1.3.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (6.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\saanv\appdata\roaming\python\python38\site-packages (from matplotlib>=3.0.0->mlxtend) (26.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.57.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.1.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\saanv\appdata\roaming\python\python38\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->mlxtend) (3.20.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\saanv\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\users\saanv\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
dataset = [
    ['Milk', 'Bread', 'Butter'],
    ['Bread', 'Butter'],
    ['Milk', 'Bread'],
    ['Milk', 'Butter'],
    ['Bread', 'Butter'],
    ['Milk', 'Bread', 'Butter'],
    ['Milk', 'Bread'],
]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_data = te.fit(dataset).transform(dataset)

df = pd.DataFrame(te_data, columns=te.columns_)

print(df)
# Out:
#    Bread  Butter   Milk
# 0   True    True   True
# 1   True    True  False
# 2   True   False   True
# 3  False    True   True
# 4   True    True  False
# 5   True    True   True
# 6   True   False   True

# %%
frequent_items = apriori(df, min_support=0.4, use_colnames=True)

print("Frequent Itemsets:")
print(frequent_items)
# Out:
# Frequent Itemsets:
#     support         itemsets
# 0  0.857143          (Bread)
# 1  0.714286         (Butter)
# 2  0.714286           (Milk)
# 3  0.571429  (Bread, Butter)
# 4  0.571429    (Bread, Milk)
# 5  0.428571   (Milk, Butter)

# %%
rules = association_rules(frequent_items, metric="confidence", min_threshold=0.6)

print("Association Rules:")
print(rules)
# Out:
# Association Rules:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0     (Bread)    (Butter)            0.857143            0.714286  0.571429
# 1    (Butter)     (Bread)            0.714286            0.857143  0.571429
# 2     (Bread)      (Milk)            0.857143            0.714286  0.571429
# 3      (Milk)     (Bread)            0.714286            0.857143  0.571429
# 4      (Milk)    (Butter)            0.714286            0.714286  0.428571
# 5    (Butter)      (Milk)            0.714286            0.714286  0.428571
#
#    confidence      lift  representativity  leverage  conviction  \
# 0    0.666667  0.933333               1.0 -0.040816    0.857143
# 1    0.800000  0.933333               1.0 -0.040816    0.714286
# 2    0.666667  0.933333               1.0 -0.040816    0.857143
# 3    0.800000  0.933333               1.0 -0.040816    0.714286
# 4    0.600000  0.840000               1.0 -0.081633    0.714286
# 5    0.600000  0.840000               1.0 -0.081633    0.714286
#
#    zhangs_metric   jaccard  certainty  kulczynski
# 0      -0.333333  0.571429  -0.166667    0.733333
# 1      -0.200000  0.571429  -0.400000    0.733333
# 2      -0.333333  0.571429  -0.166667    0.733333
# 3      -0.200000  0.571429  -0.400000    0.733333
# 4      -0.400000  0.428571  -0.400000    0.600000
# 5      -0.400000  0.428571  -0.400000    0.600000
