# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("customers-100.csv")

# Convert date
data["Subscription Date"] = pd.to_datetime(data["Subscription Date"])
data["Year"] = data["Subscription Date"].dt.year
data["Month"] = data["Subscription Date"].dt.month

data.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
METHOD 1: BOXPLOT

# %%
plt.figure()
plt.boxplot(data["Year"])
plt.title("Boxplot of Year")
plt.show()

# %%
METHOD 2: IQR METHOD

# %%
Q1 = data["Year"].quantile(0.25)
Q3 = data["Year"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_iqr = data[(data["Year"] < lower_bound) | (data["Year"] > upper_bound)]

print("IQR Outliers:")
print(outliers_iqr)
# Out:
# IQR Outliers:
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website, Year, Month]
# Index: []

# %%
METHOD 3: Z-SCORE METHOD

# %%
from scipy.stats import zscore

data["zscore"] = zscore(data["Year"])

outliers_z = data[abs(data["zscore"]) > 3]

print("Z-Score Outliers:")
print(outliers_z)
# Out:
# Z-Score Outliers:
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website, Year, Month, zscore]
# Index: []
